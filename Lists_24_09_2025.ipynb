# %% [markdown]
# <a href="https://colab.research.google.com/github/nishant6217/Python-Scalar/blob/Python-Scalar/Lists_24_09_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
students = ['nishant','aman']
print(students)
# Out:
# ['nishant', 'aman']

# %%
students = ['nishant','aman']
print(students[0])
# Out:
# nishant

# %%
a = range(0,100,6)

print(list(a))
# Out:
# [0, 6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66, 72, 78, 84, 90, 96]

# %%
students = ['nishant','aman']
print(students[-100])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3886958141.py in <cell line: 0>()
#       1 students = ['nishant','aman']
# ----> 2 print(students[-100])
#
# IndexError: list index out of range

# %%
students = ['nishant','aman']
students [1] = 'shubham'
print(students[0])
# Out:
# nishant

# %%
students = ['nishant','aman']
students [3] = 'shubham'
print(students[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-932687848.py in <cell line: 0>()
#       1 students = ['nishant','aman']
# ----> 2 students [3] = 'shubham'
#       3 print(students[0])
#
# IndexError: list assignment index out of range

# %%
students = ['nishant','aman']
x = len(students)
print(x)
# Out:
# 2

# %%
students = ['nishant','aman']
x = len(students)
for i in range(x):
    print(students[i])
# Out:
# nishant
# aman

# %%
students = ['nishant','aman']
for i in students:
    print(i)
# Out:
# nishant
# aman

# %%
names = ["A", "B", "C"]
if "B" in names:
    for i in range(len(names)-1, -1, -1):
        print(names[i], end='')
# Out:
# CBA

# %%
names = ["A", "B", "C"]

print("A" in names)
# Out:
# True

# %%
names = ["A", "B", "C","D","E","F"]
print(names[1:4])
# Out:
# ['B', 'C', 'D']

# %%
names = ["A", "B", "C","D","E","F"]
print(len(names[1:4]))
# Out:
# 3

# %%
print(names[::-2])
print(names[::2])
# Out:
# ['F', 'D', 'B']
# ['A', 'C', 'E']

# %%
nums = [10, 20, 30, 40, 50, 60]
print(nums[2:5])
# Out:
# ['a', 'b']

# %%
letters = ['a', 'b', 'c', 'd', 'e']
print(letters[:2])
# Out:
# ['a', 'b']

# %%
data = [5, 6, 7, 8, 9, 10]
print(data[3:])
# Out:
# [10, 40]

# %%
nums = [10, 20, 30, 40, 50, 60]
print(nums[::3])
# Out:
# ['f', 'e', 'd', 'c', 'b', 'a']

# %%
letters = ['a', 'b', 'c', 'd', 'e', 'f']
print(letters[::-1])
# Out:
# [2, 4, 6]

# %%
nums = [1, 2, 3, 4, 5, 6, 7]
print(nums[1:6:2])
# Out:
# [2, 4, 6]

# %%
li = [1, 2, 3]
li.append('4')
print(li)
# Out:
# 2

# %%
li = [1, 2]
print(li.pop())
# Out:
# 2

# %%
li = [1, 2]
# print(li.remove(2))

c= li.remove(2)
print(c)
# Out:
# None

# %%
li = [1, 2]
print(li.pop())

print(li)
# Out:
# 2
# [1]

# %%
# print(names+li)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 1]

# %%
# names.append(li)
# print(names[-1])
names.extend(li)
print(names)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 1, 1]

# %%
a = [1, 2]
a.extend([3])
a.append([4])
print(a)
# Out:
# [1, 2, 3, [4]]
