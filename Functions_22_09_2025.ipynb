# %% [markdown]
# <a href="https://colab.research.google.com/github/nishant6217/Python-Scalar/blob/Python-Scalar/Functions_22_09_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# area of circle
n = int(input())
def area_of_circle(r):
  print(3.14*r*r)

area_of_circle(n)
# Out:
# 2
# 12.56

# %%
# area of circle
n = int(input())
def area_of_circle(r):
  return 3.14*r*r

x=  area_of_circle(n)

print(x)
# Out:
# 2
# 12.56

# %%
# area of circle
n = int(input())
def area_of_circle(r):
  return

x=  area_of_circle(n)

print(x)
# Out:
# 5
# None

# %%
# area of circle
n = int(input())

x=  area_of_circle1(n)
print(x)

def area_of_circle1(r):
  return 3.14*r*r
# Out:
# 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-632339558.py in <cell line: 0>()
#       2 n = int(input())
#       3
# ----> 4 x=  area_of_circle1(n)
#       5 print(x)
#       6
#
# NameError: name 'area_of_circle1' is not defined

# %%
x = int(input())

def area_second_fun(n):
  area = (3.14*(n**2))
  return area

print(x)
print(area)
print(area_second_fun())
# Out:
# 10
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3305967684.py in <cell line: 0>()
#       6
#       7 print(x)
# ----> 8 print(area)
#       9 print(area_second_fun())
#
# NameError: name 'area' is not defined

# %%
i = int(input())

def print_challenge():
  i=2;
  print(i)

x = print_challenge()
print(i)
# Out:
# 3
# 2
# 3

# %%
i = int(input())

def print_challenge():
  global i
  i=2;
  print(i)

x = print_challenge()
print(i)
# Out:
# 5
# 2
# 2

# %%
def area_rectangle(l, b):
    area = l * b
area_circle(3, 4)
print(area)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2430350480.py in <cell line: 0>()
#       1 def area_rectangle(l, b):
#       2     area = l * b
# ----> 3 area_circle(3, 4)
#       4 print(area)
#
# NameError: name 'area_circle' is not defined

# %%
def foo(a):
    if(a):
        return 100
    a += 20
    return a
print(foo(0))
# Out:
# 20

# %%
def solve(a, b):
    print('Function Started')
    return 0
    c = a + b
    print('Function Ends')
c = solve(2, 3)
print(c)
# Out:
# Function Started
# 0

# %%
# palindrom

n = int(input())

orig = n

c =0
while n>0:
  last_dig = n%10
  c=c*10+last_dig;
  n=n//10

print(c)
if orig==c:
  print("Yes")
else:
  print("No")
# Out:
# 121
# 121
# Yes

# %%
test_case = int(input())

for _ in range(1,test_case+1):
  a = int(input())
  c =0

  while a > 0:
    c=c+1
    a=a//10
  print(c)
# Out:
# 1
# 234
# 3

# %%
def hello(a,b,c,d):
  print("a:",a)
  print("b:",b)
  print("c:",c)
  print("d:",d)

hello(1,2,a=3,b=4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3289542597.py in <cell line: 0>()
#       5   print("d:",d)
#       6
# ----> 7 hello(1,2,a=3,b=4)
#
# TypeError: hello() got multiple values for argument 'a'

# %%
def hello(a,b,c,d):
  print("a:",a)
  print("b:",b)
  print("c:",c)
  print("d:",d)

hello(1,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1014205009.py in <cell line: 0>()
#       5   print("d:",d)
#       6
# ----> 7 hello(1,2)
#
# TypeError: hello() missing 2 required positional arguments: 'c' and 'd'

# %%
# interest calculation
def calculate_interest(principal, time):
    rate = 7
    interest = (principal * rate * time) / 100
    return interest

c = int(input())
d= int(input())

interest = calculate_interest(10,time=10)
print(interest)
# Out:
# 2
# 3
# 7.0

# %%
def convert(t):
    return t*9/5 + 32

print(convert(20))

# Note: The Question is with respect to Python 3.0 version.
# Out:
# 68.0

# %%
def multiple_print(s, n = 1):
    print(s * n, end='')
    print() # this prints new line i.e. \n

multiple_print('Hello', 2)
multiple_print('Hello')
# Out:
# HelloHello
# Hello
